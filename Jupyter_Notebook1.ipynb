# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Yusi Chen**
# <br>Data Scientist

# %% [markdown]
# _I really enjoy problem-solving and statistical analysis, which led me to a career in data science._

# %% [markdown]
# ### In the following section, I'm going to show you how to use coding language to plot a simple linear function y=2x+1.

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(-5,5,100)
y = 2*x+1
plt.plot(x, y, '-r', label='y=2x+1')
plt.title('Graph of y=2x+1')
plt.xlabel('x', color='#1C2833')
plt.ylabel('y', color='#1C2833')
plt.legend(loc='upper left')
plt.grid()
plt.show()

# %% [markdown]
# This section mainly demonstrates:
# 1. horizontal rule
# 2. numbered lists
# 3. table
# ***

# %% [markdown]
# | NAME        | CODE          |
# | ------------- |:-------------:|
# | Horizontal Rule      | *** or --- or ___|
